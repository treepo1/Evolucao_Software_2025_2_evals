# %%
# !pip install -U transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/finiteautomata/bertweet-base-sentiment-analysis?text=Im+so+happy
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/finiteautomata/bertweet-base-sentiment-analysis?text=Im+so+happy)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# config.json:   0%|          | 0.00/949 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/540M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/540M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/338 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# bpe.codes: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# Device set to use cuda:0

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("finiteautomata/bertweet-base-sentiment-analysis")
model = AutoModelForSequenceClassification.from_pretrained("finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0

# %% [markdown]
# ## Remote Inference via Inference Providers
# Ensure you have a valid **HF_TOKEN** set in your environment. You can get your token from [your settings page](https://huggingface.co/settings/tokens). Note: running this may incur charges above the free tier.
# The following Python example shows how to run the model remotely on HF Inference Providers, automatically selecting an available inference provider for you.
# For more information on how to use the Inference Providers, please refer to our [documentation and guides](https://huggingface.co/docs/inference-providers/en/index).

# %%
import os
import json
os.environ['HF_TOKEN'] = 'YOUR_HF_TOKEN_HERE'

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="auto",
    api_key=os.environ["HF_TOKEN"],
)

def get_sentiment(text):
    """
    Get sentiment analysis for a given text using Hugging Face model.
    Returns the sentiment result or None if text is empty/None.
    """
    if not text or text.strip() == "":
        return None

    try:
        result = client.text_classification(text, model="finiteautomata/bertweet-base-sentiment-analysis")
        return result
    except Exception as e:
        print(f"Error analyzing sentiment: {e}")
        return None
def analyze_pr_sentiments(json_file_path):
    """
    Read pull requests from JSON file and analyze sentiments.
    """
    # Read the JSON file
    with open(json_file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    print(f"Repository: {data['repository']}")
    print(f"Total PRs: {data['total_prs']}")
    print(f"Timestamp: {data['timestamp']}")
    print("\n" + "="*80 + "\n")

    # Analyze each pull request
    for pr in data['pull_requests']:
        print(f"PR #{pr['number']}: {pr['title']}")
        print(f"Author: {pr['author']}")
        print(f"State: {pr['state']}")
        print(f"URL: {pr['html_url']}")

        # Analyze PR title sentiment
        print("\n--- Title Sentiment ---")
        title_sentiment = get_sentiment(pr['title'])
        if title_sentiment:
            print(f"Title: {title_sentiment}")

        # Analyze PR body sentiment
        if pr['body']:
            print("\n--- Body Sentiment ---")
            # Truncate body if too long (models have token limits)
            body_text = pr['body'][:500]  # First 500 chars
            body_sentiment = get_sentiment(body_text)
            if body_sentiment:
                print(f"Body: {body_sentiment}")

        # Analyze comments sentiments
        if pr['comments'] and len(pr['comments']) > 0:
            print(f"\n--- Comments Sentiments ({pr['total_comments']} total) ---")
            for idx, comment in enumerate(pr['comments'], 1):
                if comment['body']:
                    # Truncate comment if too long
                    comment_text = comment['body'][:500]
                    comment_sentiment = get_sentiment(comment_text)
                    if comment_sentiment:
                        print(f"Comment {idx} by {comment['author']}: {comment_sentiment}")

        print("\n" + "="*80 + "\n")

def save_sentiments_to_file(json_file_path, output_file_path):
    """
    Read pull requests from JSON file, analyze sentiments, and save to a new JSON file.
    """
    # Read the JSON file
    with open(json_file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # Analyze each pull request and add sentiment data
    for pr in data['pull_requests']:
        # Analyze PR title sentiment
        pr['title_sentiment'] = get_sentiment(pr['title'])

        # Analyze PR body sentiment
        if pr['body']:
            body_text = pr['body'][:500]
            pr['body_sentiment'] = get_sentiment(body_text)
        else:
            pr['body_sentiment'] = None

        # Analyze comments sentiments
        if pr['comments']:
            for comment in pr['comments']:
                if comment['body']:
                    comment_text = comment['body'][:500]
                    comment['sentiment'] = get_sentiment(comment_text)
                else:
                    comment['sentiment'] = None

    # Save to output file
    with open(output_file_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, indent=2, ensure_ascii=False)

    print(f"Sentiment analysis complete! Results saved to {output_file_path}")

# %%
if __name__ == "__main__":
    # Input JSON file path
    input_file = "openai_evals_prs.json"

    # Output JSON file path (with sentiments)
    output_file = "prs_with_sentiments.json"

    # Option 1: Print sentiments to console
    print("Analyzing sentiments and printing to console...\n")
    analyze_pr_sentiments(input_file)

    # Option 2: Save sentiments to a new JSON file
    print("\nSaving sentiments to file...\n")
    save_sentiments_to_file(input_file, output_file)
# Out:
# Analyzing sentiments and printing to console...
#
# Repository: openai/evals
# Total PRs: 100
# Timestamp: 2025-11-12T03:36:51.398133Z
#
# ================================================================================
#
# PR #1605: Remove incontext_rl suite with defunct dependencies
# Author: maxb-openai
# State: closed
# URL: https://github.com/openai/evals/pull/1605
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.5333474278450012), TextClassificationOutputElement(label='NEG', score=0.4538016617298126), TextClassificationOutputElement(label='POS', score=0.012850950472056866)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEG', score=0.5569808483123779), TextClassificationOutputElement(label='NEU', score=0.43640145659446716), TextClassificationOutputElement(label='POS', score=0.006617657840251923)]
#
# ================================================================================
#
# PR #1572: Updating readme to link to OpenAI hosted evals experience
# Author: dmitry-openai
# State: closed
# URL: https://github.com/openai/evals/pull/1572
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9480888843536377), TextClassificationOutputElement(label='POS', score=0.047832027077674866), TextClassificationOutputElement(label='NEG', score=0.00407905038446188)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='POS', score=0.8072941303253174), TextClassificationOutputElement(label='NEU', score=0.19118258357048035), TextClassificationOutputElement(label='NEG', score=0.0015232550213113427)]
#
# ================================================================================
#
# PR #1560: 20240930 steven exception handling usage tokens
# Author: sjadler2004
# State: closed
# URL: https://github.com/openai/evals/pull/1560
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9736759662628174), TextClassificationOutputElement(label='POS', score=0.017194967716932297), TextClassificationOutputElement(label='NEG', score=0.009128943085670471)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524e5-22427e994e3e01ae5e9dc0ef;61c49c2b-d0b2-4403-8473-f5a4c164c1d2)
#
# Bad request:
# index out of range in self
#
# ================================================================================
#
# PR #1528: [eval] Add IMO problems with exact answers
# Author: justinlinw
# State: closed
# URL: https://github.com/openai/evals/pull/1528
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9570829272270203), TextClassificationOutputElement(label='NEG', score=0.02837892808020115), TextClassificationOutputElement(label='POS', score=0.014538095332682133)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.898758053779602), TextClassificationOutputElement(label='NEG', score=0.07813882827758789), TextClassificationOutputElement(label='POS', score=0.023103056475520134)]
#
# --- Comments Sentiments (3 total) ---
# Error analyzing sentiment: (Request ID: Root=1-691524e6-2abe00196827b6b705f898b1;c3d12a07-8e90-48ce-a1f9-bd22e5476e5c)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-691524e6-4845115b29db1e0745cb34a2;1c0f7030-8e8a-4078-95bc-bedb4567932c)
#
# Bad request:
# index out of range in self
# Comment 3 by usama-openai: [TextClassificationOutputElement(label='POS', score=0.986346423625946), TextClassificationOutputElement(label='NEU', score=0.012402895838022232), TextClassificationOutputElement(label='NEG', score=0.001250740373507142)]
#
# ================================================================================
#
# PR #1525: Release 3.0.1
# Author: etr2460
# State: closed
# URL: https://github.com/openai/evals/pull/1525
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9380823373794556), TextClassificationOutputElement(label='POS', score=0.05268334969878197), TextClassificationOutputElement(label='NEG', score=0.009234321303665638)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.9380823373794556), TextClassificationOutputElement(label='POS', score=0.05268334969878197), TextClassificationOutputElement(label='NEG', score=0.009234321303665638)]
#
# ================================================================================
#
# PR #1524: Make the torch dep optional
# Author: etr2460
# State: closed
# URL: https://github.com/openai/evals/pull/1524
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9046326875686646), TextClassificationOutputElement(label='NEG', score=0.07387703657150269), TextClassificationOutputElement(label='POS', score=0.021490249782800674)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.9350012540817261), TextClassificationOutputElement(label='POS', score=0.04055694863200188), TextClassificationOutputElement(label='NEG', score=0.024441765621304512)]
#
# ================================================================================
#
# PR #1520: Release 3.0.0
# Author: etr2460
# State: closed
# URL: https://github.com/openai/evals/pull/1520
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9459292888641357), TextClassificationOutputElement(label='POS', score=0.04337785765528679), TextClassificationOutputElement(label='NEG', score=0.01069276686757803)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.8124639987945557), TextClassificationOutputElement(label='NEG', score=0.13237038254737854), TextClassificationOutputElement(label='POS', score=0.05516554042696953)]
#
# ================================================================================
#
# PR #1519: Unpin dependencies
# Author: hauntsaninja
# State: closed
# URL: https://github.com/openai/evals/pull/1519
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9406487941741943), TextClassificationOutputElement(label='POS', score=0.031046027317643166), TextClassificationOutputElement(label='NEG', score=0.028305241838097572)]
#
# ================================================================================
#
# PR #1517: Allow for evals with no args
# Author: thesofakillers
# State: closed
# URL: https://github.com/openai/evals/pull/1517
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.95887690782547), TextClassificationOutputElement(label='POS', score=0.022711224853992462), TextClassificationOutputElement(label='NEG', score=0.018411926925182343)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524e8-63de83591628db756a1d3132;2421443f-6be0-46e3-982b-79b790e20676)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9766849279403687), TextClassificationOutputElement(label='NEU', score=0.021375857293605804), TextClassificationOutputElement(label='NEG', score=0.001939237117767334)]
#
# ================================================================================
#
# PR #1516: Relax version constraint for `playwright` module
# Author: danesherbs
# State: closed
# URL: https://github.com/openai/evals/pull/1516
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.951752781867981), TextClassificationOutputElement(label='POS', score=0.043151479214429855), TextClassificationOutputElement(label='NEG', score=0.005095718428492546)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.9611690640449524), TextClassificationOutputElement(label='POS', score=0.03482998162508011), TextClassificationOutputElement(label='NEG', score=0.004000945016741753)]
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.929833173751831), TextClassificationOutputElement(label='NEU', score=0.06878749281167984), TextClassificationOutputElement(label='NEG', score=0.001379291177727282)]
#
# ================================================================================
#
# PR #1514: Switch from pyzstd to zstandard
# Author: josnyder-2
# State: closed
# URL: https://github.com/openai/evals/pull/1514
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9223920702934265), TextClassificationOutputElement(label='POS', score=0.06413322687149048), TextClassificationOutputElement(label='NEG', score=0.013474632985889912)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='POS', score=0.8795227408409119), TextClassificationOutputElement(label='NEU', score=0.11907416582107544), TextClassificationOutputElement(label='NEG', score=0.0014031181344762444)]
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by etr2460: [TextClassificationOutputElement(label='NEU', score=0.7894108295440674), TextClassificationOutputElement(label='NEG', score=0.19159093499183655), TextClassificationOutputElement(label='POS', score=0.01899818517267704)]
#
# ================================================================================
#
# PR #1512: Remove citation prediction eval
# Author: ojaffe
# State: closed
# URL: https://github.com/openai/evals/pull/1512
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.6926565170288086), TextClassificationOutputElement(label='NEG', score=0.2945513427257538), TextClassificationOutputElement(label='POS', score=0.012792176567018032)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.8746886849403381), TextClassificationOutputElement(label='NEG', score=0.11773795634508133), TextClassificationOutputElement(label='POS', score=0.007573362439870834)]
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='NEU', score=0.8203033208847046), TextClassificationOutputElement(label='POS', score=0.16530156135559082), TextClassificationOutputElement(label='NEG', score=0.014395109377801418)]
#
# ================================================================================
#
# PR #1507: Update ReadMe with New Cookbook link
# Author: royziv11
# State: closed
# URL: https://github.com/openai/evals/pull/1507
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9418244361877441), TextClassificationOutputElement(label='POS', score=0.054564375430345535), TextClassificationOutputElement(label='NEG', score=0.003611154854297638)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.8859091997146606), TextClassificationOutputElement(label='NEG', score=0.06620102375745773), TextClassificationOutputElement(label='POS', score=0.04788980633020401)]
#
# ================================================================================
#
# PR #1506: Updates on existing solvers and bugged tool eval
# Author: ojaffe
# State: closed
# URL: https://github.com/openai/evals/pull/1506
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.8556467890739441), TextClassificationOutputElement(label='NEG', score=0.13218684494495392), TextClassificationOutputElement(label='POS', score=0.01216635387390852)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524ea-0be7e21b07561c6e4b220fc6;bb8275fd-230b-4d58-982c-1b2e0b764a16)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9882715344429016), TextClassificationOutputElement(label='NEU', score=0.009342780336737633), TextClassificationOutputElement(label='NEG', score=0.002385699888691306)]
#
# ================================================================================
#
# PR #1503: Add Gemini Solver
# Author: ojaffe
# State: closed
# URL: https://github.com/openai/evals/pull/1503
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9396146535873413), TextClassificationOutputElement(label='POS', score=0.052701495587825775), TextClassificationOutputElement(label='NEG', score=0.007683860138058662)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.968168318271637), TextClassificationOutputElement(label='POS', score=0.027445528656244278), TextClassificationOutputElement(label='NEG', score=0.004386273678392172)]
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9891497492790222), TextClassificationOutputElement(label='NEU', score=0.009677060879766941), TextClassificationOutputElement(label='NEG', score=0.0011731608537957072)]
#
# ================================================================================
#
# PR #1502: TogetherSolver
# Author: thesofakillers
# State: closed
# URL: https://github.com/openai/evals/pull/1502
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9322314262390137), TextClassificationOutputElement(label='POS', score=0.062385473400354385), TextClassificationOutputElement(label='NEG', score=0.0053830938413739204)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524ea-6d3a634d65d55b7100bcc2e7;af8bb16b-5efa-4a2a-829c-f501ce9c72d6)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9712139368057251), TextClassificationOutputElement(label='NEU', score=0.02768031321465969), TextClassificationOutputElement(label='NEG', score=0.0011057829251512885)]
#
# ================================================================================
#
# PR #1501: Unified create_retrying for all solvers
# Author: ojaffe
# State: closed
# URL: https://github.com/openai/evals/pull/1501
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9148989915847778), TextClassificationOutputElement(label='POS', score=0.08045228570699692), TextClassificationOutputElement(label='NEG', score=0.004648739472031593)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.9465396404266357), TextClassificationOutputElement(label='POS', score=0.04243093356490135), TextClassificationOutputElement(label='NEG', score=0.011029456742107868)]
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.991762638092041), TextClassificationOutputElement(label='NEU', score=0.006523703690618277), TextClassificationOutputElement(label='NEG', score=0.0017137059476226568)]
#
# ================================================================================
#
# PR #1500: Add Multi-Step Web Tasks
# Author: danesherbs
# State: closed
# URL: https://github.com/openai/evals/pull/1500
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9615190029144287), TextClassificationOutputElement(label='POS', score=0.027166791260242462), TextClassificationOutputElement(label='NEG', score=0.011314183473587036)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524eb-68bf0e2f6532cdc710453d35;aaf3cb53-de49-486d-8349-5dd23d5fb690)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9920021295547485), TextClassificationOutputElement(label='NEU', score=0.006480826996266842), TextClassificationOutputElement(label='NEG', score=0.0015170612605288625)]
#
# ================================================================================
#
# PR #1499: Add 20 questions eval
# Author: inwaves
# State: closed
# URL: https://github.com/openai/evals/pull/1499
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9584600329399109), TextClassificationOutputElement(label='POS', score=0.02346237376332283), TextClassificationOutputElement(label='NEG', score=0.018077591434121132)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524ec-166ab4f634104402149d960e;7a3a60e4-1663-4e2f-b2ae-edb016ae5434)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9882012009620667), TextClassificationOutputElement(label='NEU', score=0.009819811210036278), TextClassificationOutputElement(label='NEG', score=0.00197892589494586)]
#
# ================================================================================
#
# PR #1498: AnthropicSolver
# Author: thesofakillers
# State: closed
# URL: https://github.com/openai/evals/pull/1498
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9332065582275391), TextClassificationOutputElement(label='POS', score=0.05483691021800041), TextClassificationOutputElement(label='NEG', score=0.01195650827139616)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524ec-4b1d102a502c752c5c25ffcc;c6b5e466-784a-47f5-b0ab-a3ddf344654e)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9868137836456299), TextClassificationOutputElement(label='NEU', score=0.011988706886768341), TextClassificationOutputElement(label='NEG', score=0.0011974893277511)]
#
# ================================================================================
#
# PR #1497: Add skill acquisition eval
# Author: inwaves
# State: closed
# URL: https://github.com/openai/evals/pull/1497
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9195349812507629), TextClassificationOutputElement(label='POS', score=0.07520268112421036), TextClassificationOutputElement(label='NEG', score=0.005262226331979036)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524ed-126ac6da660397563ce37041;bd578240-968e-4ecd-b5c4-15f0876c232a)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9925057291984558), TextClassificationOutputElement(label='NEU', score=0.005925023928284645), TextClassificationOutputElement(label='NEG', score=0.0015692423330619931)]
#
# ================================================================================
#
# PR #1496: Add Human-Relative MLAgentBench
# Author: danesherbs
# State: closed
# URL: https://github.com/openai/evals/pull/1496
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9650134444236755), TextClassificationOutputElement(label='POS', score=0.02790100686252117), TextClassificationOutputElement(label='NEG', score=0.00708553334698081)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524ed-545e082779b11dd6513b45f3;3112a84e-79bd-4c7b-adb2-ed7376f942c0)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9921736717224121), TextClassificationOutputElement(label='NEU', score=0.006355802994221449), TextClassificationOutputElement(label='NEG', score=0.0014705450739711523)]
#
# ================================================================================
#
# PR #1492: Add Function Deduction eval
# Author: james-aung-aisi
# State: closed
# URL: https://github.com/openai/evals/pull/1492
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9559935331344604), TextClassificationOutputElement(label='POS', score=0.02739735320210457), TextClassificationOutputElement(label='NEG', score=0.016609158366918564)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524ed-74b728ff530bfb324b6f27f3;0eecbfe4-da97-495b-ae0d-27e2931f8e74)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9916268587112427), TextClassificationOutputElement(label='NEU', score=0.0068458374589681625), TextClassificationOutputElement(label='NEG', score=0.0015272374730557203)]
#
# ================================================================================
#
# PR #1491: Add In-Context RL eval
# Author: james-aung-aisi
# State: closed
# URL: https://github.com/openai/evals/pull/1491
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9660370945930481), TextClassificationOutputElement(label='POS', score=0.027544168755412102), TextClassificationOutputElement(label='NEG', score=0.00641880976036191)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524ee-0532601a6e2d5be21c1b6241;b8cd988f-46de-4f53-a6fa-489cfae9fa23)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (2 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='NEG', score=0.9604024291038513), TextClassificationOutputElement(label='NEU', score=0.03740030154585838), TextClassificationOutputElement(label='POS', score=0.0021972416434437037)]
# Comment 2 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9702767133712769), TextClassificationOutputElement(label='NEU', score=0.02860844135284424), TextClassificationOutputElement(label='NEG', score=0.001114817801862955)]
#
# ================================================================================
#
# PR #1490: Already Said That Eval
# Author: thesofakillers
# State: closed
# URL: https://github.com/openai/evals/pull/1490
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9606007933616638), TextClassificationOutputElement(label='POS', score=0.023354267701506615), TextClassificationOutputElement(label='NEG', score=0.016044946387410164)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524ee-688c4bbc472a5d865ee1dae9;9155b3e9-b5a0-486d-954a-0d306709072e)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (2 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='NEG', score=0.7532896995544434), TextClassificationOutputElement(label='NEU', score=0.23960280418395996), TextClassificationOutputElement(label='POS', score=0.0071075051091611385)]
# Comment 2 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9923457503318787), TextClassificationOutputElement(label='NEU', score=0.005707288160920143), TextClassificationOutputElement(label='NEG', score=0.0019469964317977428)]
#
# ================================================================================
#
# PR #1489: Track the Stat Eval
# Author: thesofakillers
# State: closed
# URL: https://github.com/openai/evals/pull/1489
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9618786573410034), TextClassificationOutputElement(label='POS', score=0.027921419590711594), TextClassificationOutputElement(label='NEG', score=0.010199853219091892)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524ef-1508fe0107e66a463d599c5e;607d3159-98fe-40e8-8a56-ad1a75261f2e)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (5 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='NEG', score=0.7532896995544434), TextClassificationOutputElement(label='NEU', score=0.23960280418395996), TextClassificationOutputElement(label='POS', score=0.0071075051091611385)]
# Comment 2 by JunShern: [TextClassificationOutputElement(label='NEU', score=0.7733075022697449), TextClassificationOutputElement(label='NEG', score=0.21663951873779297), TextClassificationOutputElement(label='POS', score=0.010052984580397606)]
# Comment 3 by thesofakillers: [TextClassificationOutputElement(label='NEU', score=0.5011711716651917), TextClassificationOutputElement(label='POS', score=0.44587990641593933), TextClassificationOutputElement(label='NEG', score=0.05294894054532051)]
# Comment 4 by JunShern: [TextClassificationOutputElement(label='NEG', score=0.7675667405128479), TextClassificationOutputElement(label='NEU', score=0.21890315413475037), TextClassificationOutputElement(label='POS', score=0.01353011280298233)]
# Comment 5 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9920554757118225), TextClassificationOutputElement(label='NEU', score=0.006250633392482996), TextClassificationOutputElement(label='NEG', score=0.0016938967164605856)]
#
# ================================================================================
#
# PR #1488: Identifying Variables Eval
# Author: thesofakillers
# State: closed
# URL: https://github.com/openai/evals/pull/1488
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9524338841438293), TextClassificationOutputElement(label='POS', score=0.035061728209257126), TextClassificationOutputElement(label='NEG', score=0.012504376471042633)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524f0-0a9a2a6358c9257328295962;1800c12a-1846-4c70-ac8f-25db2235ec30)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (11 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='NEG', score=0.8988878130912781), TextClassificationOutputElement(label='NEU', score=0.09765957295894623), TextClassificationOutputElement(label='POS', score=0.0034526486415416002)]
# Comment 2 by JunShern: [TextClassificationOutputElement(label='NEU', score=0.8752329349517822), TextClassificationOutputElement(label='NEG', score=0.10535227507352829), TextClassificationOutputElement(label='POS', score=0.019414842128753662)]
# Comment 3 by JunShern: [TextClassificationOutputElement(label='NEU', score=0.9714266061782837), TextClassificationOutputElement(label='POS', score=0.01441008411347866), TextClassificationOutputElement(label='NEG', score=0.014163305051624775)]
# Comment 4 by JunShern: [TextClassificationOutputElement(label='NEG', score=0.8621901869773865), TextClassificationOutputElement(label='NEU', score=0.134434312582016), TextClassificationOutputElement(label='POS', score=0.0033754033502191305)]
# Comment 5 by JunShern: [TextClassificationOutputElement(label='NEU', score=0.7230545878410339), TextClassificationOutputElement(label='NEG', score=0.2628486454486847), TextClassificationOutputElement(label='POS', score=0.01409671176224947)]
# Comment 6 by thesofakillers: [TextClassificationOutputElement(label='NEU', score=0.9358262419700623), TextClassificationOutputElement(label='POS', score=0.05308955907821655), TextClassificationOutputElement(label='NEG', score=0.01108416635543108)]
# Comment 7 by thesofakillers: [TextClassificationOutputElement(label='NEG', score=0.5715652704238892), TextClassificationOutputElement(label='NEU', score=0.4132673144340515), TextClassificationOutputElement(label='POS', score=0.015167389065027237)]
# Error analyzing sentiment: (Request ID: Root=1-691524f1-64e2ee650fea6ec83bfbd94d;b1a7f0c3-d0e3-457a-a76e-0c327b10ef4c)
#
# Bad request:
# index out of range in self
# Comment 9 by JunShern: [TextClassificationOutputElement(label='POS', score=0.962794303894043), TextClassificationOutputElement(label='NEU', score=0.03583740070462227), TextClassificationOutputElement(label='NEG', score=0.001368367811664939)]
# Comment 10 by JunShern: [TextClassificationOutputElement(label='POS', score=0.6998260617256165), TextClassificationOutputElement(label='NEU', score=0.2963741421699524), TextClassificationOutputElement(label='NEG', score=0.003799728350713849)]
# Comment 11 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9865291118621826), TextClassificationOutputElement(label='NEU', score=0.01222375687211752), TextClassificationOutputElement(label='NEG', score=0.0012470782967284322)]
#
# ================================================================================
#
# PR #1487: Can't Do That Anymore Eval
# Author: ojaffe
# State: closed
# URL: https://github.com/openai/evals/pull/1487
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEG', score=0.9777088761329651), TextClassificationOutputElement(label='NEU', score=0.01868821121752262), TextClassificationOutputElement(label='POS', score=0.0036029177717864513)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524f2-3b74fc606091dc957a377699;cbce8b17-e129-4134-8086-84346011fc53)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9927983283996582), TextClassificationOutputElement(label='NEU', score=0.004614841192960739), TextClassificationOutputElement(label='NEG', score=0.0025867638178169727)]
#
# ================================================================================
#
# PR #1486: Bugged Tools Eval
# Author: ojaffe
# State: closed
# URL: https://github.com/openai/evals/pull/1486
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEG', score=0.6230921149253845), TextClassificationOutputElement(label='NEU', score=0.36903271079063416), TextClassificationOutputElement(label='POS', score=0.007875111885368824)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524f2-3b4cbe820530c3344577624f;3ca9c066-05ec-4b41-a73e-f4ed94cd46c0)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9929986000061035), TextClassificationOutputElement(label='NEU', score=0.004577989224344492), TextClassificationOutputElement(label='NEG', score=0.0024233944714069366)]
#
# ================================================================================
#
# PR #1485: Error Recovery Eval
# Author: ojaffe
# State: closed
# URL: https://github.com/openai/evals/pull/1485
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.8366088271141052), TextClassificationOutputElement(label='NEG', score=0.14783872663974762), TextClassificationOutputElement(label='POS', score=0.015552457422018051)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524f3-70c0526c0ef1615723825662;ba5d146d-2de6-437e-9cea-63f257428f65)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9848527312278748), TextClassificationOutputElement(label='NEU', score=0.013931176625192165), TextClassificationOutputElement(label='NEG', score=0.0012161624617874622)]
#
# ================================================================================
#
# PR #1483: Updates on existing evals; readmes; solvers
# Author: ojaffe
# State: closed
# URL: https://github.com/openai/evals/pull/1483
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9686482548713684), TextClassificationOutputElement(label='POS', score=0.024619920179247856), TextClassificationOutputElement(label='NEG', score=0.006731860805302858)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='POS', score=0.5077522993087769), TextClassificationOutputElement(label='NEU', score=0.4863072633743286), TextClassificationOutputElement(label='NEG', score=0.005940452218055725)]
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.867575466632843), TextClassificationOutputElement(label='NEU', score=0.12920287251472473), TextClassificationOutputElement(label='NEG', score=0.0032216710969805717)]
#
# ================================================================================
#
# PR #1482: Address sporadic hanging of evals on certain samples
# Author: thesofakillers
# State: closed
# URL: https://github.com/openai/evals/pull/1482
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9524580836296082), TextClassificationOutputElement(label='NEG', score=0.04012477025389671), TextClassificationOutputElement(label='POS', score=0.007417089771479368)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEG', score=0.6753634214401245), TextClassificationOutputElement(label='NEU', score=0.3192085027694702), TextClassificationOutputElement(label='POS', score=0.00542814377695322)]
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by etr2460: [TextClassificationOutputElement(label='POS', score=0.9400992393493652), TextClassificationOutputElement(label='NEU', score=0.05811402574181557), TextClassificationOutputElement(label='NEG', score=0.0017867530696094036)]
#
# ================================================================================
#
# PR #1481: Drop two datasets from steganography
# Author: thesofakillers
# State: closed
# URL: https://github.com/openai/evals/pull/1481
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEG', score=0.5805526375770569), TextClassificationOutputElement(label='NEU', score=0.41010451316833496), TextClassificationOutputElement(label='POS', score=0.009342857636511326)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.8702983260154724), TextClassificationOutputElement(label='NEG', score=0.09987974911928177), TextClassificationOutputElement(label='POS', score=0.029821932315826416)]
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9677146077156067), TextClassificationOutputElement(label='NEU', score=0.030926719307899475), TextClassificationOutputElement(label='NEG', score=0.0013586531858891249)]
#
# ================================================================================
#
# PR #1480: Add info about logging and link to logviz
# Author: JunShern
# State: closed
# URL: https://github.com/openai/evals/pull/1480
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9713197946548462), TextClassificationOutputElement(label='POS', score=0.021834682673215866), TextClassificationOutputElement(label='NEG', score=0.006845483090728521)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='POS', score=0.9774047136306763), TextClassificationOutputElement(label='NEU', score=0.02165025845170021), TextClassificationOutputElement(label='NEG', score=0.0009449999779462814)]
#
# ================================================================================
#
# PR #1468: Suppress 'HTTP/1.1 200 OK' logs from openai library
# Author: JunShern
# State: closed
# URL: https://github.com/openai/evals/pull/1468
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.629219114780426), TextClassificationOutputElement(label='NEG', score=0.360331654548645), TextClassificationOutputElement(label='POS', score=0.010449247434735298)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524f5-0b49623432795f1e41d57a6a;a2d94185-b5bb-4a69-a2ff-f2a89d99a47c)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (2 total) ---
# Comment 1 by johny-b: [TextClassificationOutputElement(label='NEU', score=0.6950387358665466), TextClassificationOutputElement(label='POS', score=0.30202919244766235), TextClassificationOutputElement(label='NEG', score=0.002932098228484392)]
# Comment 2 by etr2460: [TextClassificationOutputElement(label='POS', score=0.9648768901824951), TextClassificationOutputElement(label='NEU', score=0.03393161669373512), TextClassificationOutputElement(label='NEG', score=0.0011915109353139997)]
#
# ================================================================================
#
# PR #1464: Fix small typos and inconsistencies in README
# Author: kwinkunks
# State: closed
# URL: https://github.com/openai/evals/pull/1464
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEG', score=0.7455760836601257), TextClassificationOutputElement(label='NEU', score=0.24740955233573914), TextClassificationOutputElement(label='POS', score=0.0070143332704901695)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524f5-3719ecc10829f58d5a91a170;66d4d1a2-bee0-4b5b-b1ab-f16605b37ccf)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by logankilpatrick: [TextClassificationOutputElement(label='POS', score=0.9729347229003906), TextClassificationOutputElement(label='NEU', score=0.02545846812427044), TextClassificationOutputElement(label='NEG', score=0.0016068010590970516)]
#
# ================================================================================
#
# PR #1461: Updates for Solvers
# Author: JunShern
# State: closed
# URL: https://github.com/openai/evals/pull/1461
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9574108719825745), TextClassificationOutputElement(label='POS', score=0.03531336411833763), TextClassificationOutputElement(label='NEG', score=0.007275870069861412)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524f6-7f2158e63765d6255033b69e;9f541dd0-5ff3-4a0d-b0bc-63393bf5c5a6)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by etr2460: [TextClassificationOutputElement(label='POS', score=0.9624011516571045), TextClassificationOutputElement(label='NEU', score=0.03622583672404289), TextClassificationOutputElement(label='NEG', score=0.0013730028877034783)]
#
# ================================================================================
#
# PR #1460: Logged spec now includes overridden args
# Author: ojaffe
# State: closed
# URL: https://github.com/openai/evals/pull/1460
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.946063756942749), TextClassificationOutputElement(label='NEG', score=0.03266160562634468), TextClassificationOutputElement(label='POS', score=0.021274631842970848)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524f6-39e4ad0904c7a98963212b68;1756cc75-a9d7-4039-acb7-736e20311e5f)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9575014710426331), TextClassificationOutputElement(label='NEU', score=0.04120263829827309), TextClassificationOutputElement(label='NEG', score=0.0012958717998117208)]
#
# ================================================================================
#
# PR #1453: Add eval yaml for Theory of Mind eval
# Author: ojaffe
# State: closed
# URL: https://github.com/openai/evals/pull/1453
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.964191198348999), TextClassificationOutputElement(label='POS', score=0.029519423842430115), TextClassificationOutputElement(label='NEG', score=0.006289387121796608)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.815007746219635), TextClassificationOutputElement(label='NEG', score=0.17070026695728302), TextClassificationOutputElement(label='POS', score=0.014292048290371895)]
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.957099199295044), TextClassificationOutputElement(label='NEU', score=0.04095890745520592), TextClassificationOutputElement(label='NEG', score=0.0019419204909354448)]
#
# ================================================================================
#
# PR #1452: Add run_id to final_report from LocalRecorder
# Author: ianmckenzie-oai
# State: closed
# URL: https://github.com/openai/evals/pull/1452
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9707503318786621), TextClassificationOutputElement(label='POS', score=0.021097538992762566), TextClassificationOutputElement(label='NEG', score=0.00815210398286581)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEG', score=0.7942919731140137), TextClassificationOutputElement(label='NEU', score=0.20100073516368866), TextClassificationOutputElement(label='POS', score=0.004707255866378546)]
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by JunShern: [TextClassificationOutputElement(label='POS', score=0.9854825735092163), TextClassificationOutputElement(label='NEU', score=0.013138826005160809), TextClassificationOutputElement(label='NEG', score=0.0013785806950181723)]
#
# ================================================================================
#
# PR #1451: Fix formatting/typing so pre-commit hooks pass
# Author: ianmckenzie-oai
# State: closed
# URL: https://github.com/openai/evals/pull/1451
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.8941558599472046), TextClassificationOutputElement(label='NEG', score=0.07522623986005783), TextClassificationOutputElement(label='POS', score=0.03061794489622116)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524f8-4a3ea668055a0e623e343655;07dcaa2c-1d8b-46d9-b047-808d428fd81a)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by etr2460: [TextClassificationOutputElement(label='POS', score=0.763760507106781), TextClassificationOutputElement(label='NEU', score=0.22663745284080505), TextClassificationOutputElement(label='NEG', score=0.009602061472833157)]
#
# ================================================================================
#
# PR #1450: Improve MMMU performance with prompt engineering
# Author: etr2460
# State: closed
# URL: https://github.com/openai/evals/pull/1450
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='POS', score=0.666348397731781), TextClassificationOutputElement(label='NEU', score=0.3301973342895508), TextClassificationOutputElement(label='NEG', score=0.0034542211797088385)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='POS', score=0.9374077320098877), TextClassificationOutputElement(label='NEU', score=0.061037641018629074), TextClassificationOutputElement(label='NEG', score=0.0015546249924227595)]
#
# ================================================================================
#
# PR #1449: Log model and usage stats in `record.sampling`
# Author: JunShern
# State: closed
# URL: https://github.com/openai/evals/pull/1449
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9762480854988098), TextClassificationOutputElement(label='POS', score=0.01614559069275856), TextClassificationOutputElement(label='NEG', score=0.00760634196922183)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524f8-5c75e2381faec1b634d1881d;ded1e327-c28c-4aa9-836e-adb1d896f87f)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Error analyzing sentiment: (Request ID: Root=1-691524f9-551171e9077e84172420564c;6881c081-aca4-4d76-b213-0057920a5a65)
#
# Bad request:
# index out of range in self
#
# ================================================================================
#
# PR #1447: Randomly select MMMU answer when none is returned from the model
# Author: etr2460
# State: closed
# URL: https://github.com/openai/evals/pull/1447
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9524253010749817), TextClassificationOutputElement(label='NEG', score=0.038718946278095245), TextClassificationOutputElement(label='POS', score=0.008855788968503475)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.8678959012031555), TextClassificationOutputElement(label='POS', score=0.11866145581007004), TextClassificationOutputElement(label='NEG', score=0.01344265602529049)]
#
# ================================================================================
#
# PR #1445: Fix Pydantic warning on data_test run
# Author: inwaves
# State: closed
# URL: https://github.com/openai/evals/pull/1445
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEG', score=0.8017946481704712), TextClassificationOutputElement(label='NEU', score=0.19204393029212952), TextClassificationOutputElement(label='POS', score=0.006161444820463657)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-691524f9-28e9dfb879edca1c442fc9b5;e7c2c842-e7ca-4246-b0ac-799983d935f7)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by etr2460: [TextClassificationOutputElement(label='POS', score=0.863884687423706), TextClassificationOutputElement(label='NEU', score=0.1294168382883072), TextClassificationOutputElement(label='NEG', score=0.006698426324874163)]
#
# ================================================================================
#
# PR #1444: Release 2.0.0
# Author: etr2460
# State: closed
# URL: https://github.com/openai/evals/pull/1444
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9457405209541321), TextClassificationOutputElement(label='POS', score=0.04185465723276138), TextClassificationOutputElement(label='NEG', score=0.012404818087816238)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.6062763929367065), TextClassificationOutputElement(label='POS', score=0.388999879360199), TextClassificationOutputElement(label='NEG', score=0.004723770078271627)]
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by katyhshi: [TextClassificationOutputElement(label='POS', score=0.542134165763855), TextClassificationOutputElement(label='NEU', score=0.4007279574871063), TextClassificationOutputElement(label='NEG', score=0.05713783949613571)]
#
# ================================================================================
#
# PR #1443: Use the API key for testing evals in CI
# Author: etr2460
# State: closed
# URL: https://github.com/openai/evals/pull/1443
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9635370969772339), TextClassificationOutputElement(label='POS', score=0.029358893632888794), TextClassificationOutputElement(label='NEG', score=0.0071040126495063305)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.9604663848876953), TextClassificationOutputElement(label='NEG', score=0.024971304461359978), TextClassificationOutputElement(label='POS', score=0.014562210999429226)]
#
# ================================================================================
#
# PR #1442: Add MMMU evals and runner
# Author: etr2460
# State: closed
# URL: https://github.com/openai/evals/pull/1442
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9732955098152161), TextClassificationOutputElement(label='POS', score=0.01765509694814682), TextClassificationOutputElement(label='NEG', score=0.00904939416795969)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.9625192284584045), TextClassificationOutputElement(label='POS', score=0.019149402156472206), TextClassificationOutputElement(label='NEG', score=0.018331436440348625)]
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by logankilpatrick: [TextClassificationOutputElement(label='NEU', score=0.7920225858688354), TextClassificationOutputElement(label='POS', score=0.20142798125743866), TextClassificationOutputElement(label='NEG', score=0.006549514830112457)]
#
# ================================================================================
#
# PR #1441: Run tests on all commits to main
# Author: etr2460
# State: closed
# URL: https://github.com/openai/evals/pull/1441
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9744473695755005), TextClassificationOutputElement(label='NEG', score=0.01316002570092678), TextClassificationOutputElement(label='POS', score=0.012392624281346798)]
#
# --- Body Sentiment ---
# Body: [TextClassificationOutputElement(label='NEU', score=0.8968437314033508), TextClassificationOutputElement(label='POS', score=0.09425527602434158), TextClassificationOutputElement(label='NEG', score=0.00890096090734005)]
#
# ================================================================================
#
# PR #1440: Fix branch tests with empty API Key
# Author: etr2460
# State: closed
# URL: https://github.com/openai/evals/pull/1440
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.6316084861755371), TextClassificationOutputElement(label='NEG', score=0.3583392798900604), TextClassificationOutputElement(label='POS', score=0.010052315890789032)]
#
# --- Body Sentiment ---
# ...
#
# PR #1353: add Schelling Point eval
# Author: ianmckenzie-oai
# State: closed
# URL: https://github.com/openai/evals/pull/1353
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9631277918815613), TextClassificationOutputElement(label='POS', score=0.02856934629380703), TextClassificationOutputElement(label='NEG', score=0.008302842266857624)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-6915250f-24fc67b7190c73c124da971b;529836f6-2ba0-4e3b-bf21-1ecfdb91f3e8)
#
# Bad request:
# index out of range in self
#
# ================================================================================
#
# PR #1352: add Ballot Proposal eval
# Author: ianmckenzie-oai
# State: closed
# URL: https://github.com/openai/evals/pull/1352
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.968573272228241), TextClassificationOutputElement(label='POS', score=0.023926325142383575), TextClassificationOutputElement(label='NEG', score=0.007500342093408108)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-6915250f-1f39473358c9b0e966947bc4;c98b62ef-1b62-45b8-a2b5-7e9a34dfe90e)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (2 total) ---
# Comment 1 by sjadler2004: [TextClassificationOutputElement(label='NEU', score=0.6229346990585327), TextClassificationOutputElement(label='POS', score=0.36826086044311523), TextClassificationOutputElement(label='NEG', score=0.008804459124803543)]
# Comment 2 by andrew-openai: [TextClassificationOutputElement(label='NEU', score=0.625533401966095), TextClassificationOutputElement(label='NEG', score=0.36195191740989685), TextClassificationOutputElement(label='POS', score=0.01251467689871788)]
#
# ================================================================================
#
# PR #1351: add MakeMeSay eval
# Author: ianmckenzie-oai
# State: closed
# URL: https://github.com/openai/evals/pull/1351
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.946292519569397), TextClassificationOutputElement(label='POS', score=0.04489921033382416), TextClassificationOutputElement(label='NEG', score=0.008808337152004242)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-69152510-6fc2990a7dc771695844f826;b039121c-8ab7-4b66-8002-f2dd4bc17bb5)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (2 total) ---
# Comment 1 by andrew-openai: [TextClassificationOutputElement(label='NEG', score=0.7166867256164551), TextClassificationOutputElement(label='NEU', score=0.2658126950263977), TextClassificationOutputElement(label='POS', score=0.017500577494502068)]
# Comment 2 by andrew-openai: [TextClassificationOutputElement(label='POS', score=0.9918236136436462), TextClassificationOutputElement(label='NEU', score=0.006185135804116726), TextClassificationOutputElement(label='NEG', score=0.0019912966527044773)]
#
# ================================================================================
#
# PR #1349: adding eval osm_mapping
# Author: adrianmargin
# State: closed
# URL: https://github.com/openai/evals/pull/1349
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9483959674835205), TextClassificationOutputElement(label='POS', score=0.04478325694799423), TextClassificationOutputElement(label='NEG', score=0.006820754613727331)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-69152510-69184367118cdd845aea396c;3840d0a5-1d77-47e2-a11b-d9b65b16afc7)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (3 total) ---
# Error analyzing sentiment: (Request ID: Root=1-69152510-7778a6324163c4a67b87d60c;fc76a471-d1ee-49b3-8b89-3c6f20f47793)
#
# Bad request:
# index out of range in self
# Comment 2 by usama-openai: [TextClassificationOutputElement(label='POS', score=0.7156047224998474), TextClassificationOutputElement(label='NEU', score=0.2796502411365509), TextClassificationOutputElement(label='NEG', score=0.004744970705360174)]
# Comment 3 by usama-openai: [TextClassificationOutputElement(label='POS', score=0.986346423625946), TextClassificationOutputElement(label='NEU', score=0.012402895838022232), TextClassificationOutputElement(label='NEG', score=0.001250740373507142)]
#
# ================================================================================
#
# PR #1347: Dynamic Argument Integration for Registered Completion Functions
# Author: douglasmonsky
# State: closed
# URL: https://github.com/openai/evals/pull/1347
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9687032699584961), TextClassificationOutputElement(label='POS', score=0.025106171146035194), TextClassificationOutputElement(label='NEG', score=0.0061906129121780396)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-69152511-0c0e11511f95910c5a979875;50817b7f-837d-4507-a052-3dce462125c0)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by jwang47: [TextClassificationOutputElement(label='POS', score=0.9921351671218872), TextClassificationOutputElement(label='NEU', score=0.005985229276120663), TextClassificationOutputElement(label='NEG', score=0.0018796637887135148)]
#
# ================================================================================
#
# PR #1345: [Eval] Add eval for fixing word spacing for Korean sentences
# Author: woniesong92
# State: closed
# URL: https://github.com/openai/evals/pull/1345
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9562578201293945), TextClassificationOutputElement(label='NEG', score=0.029066722840070724), TextClassificationOutputElement(label='POS', score=0.014675467275083065)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-69152511-3b65d25b18849483240a6109;29a4c805-d718-4d6e-975a-e84c8f163536)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (1 total) ---
# Comment 1 by usama-openai: [TextClassificationOutputElement(label='POS', score=0.9906548857688904), TextClassificationOutputElement(label='NEU', score=0.007968220859766006), TextClassificationOutputElement(label='NEG', score=0.0013768754433840513)]
#
# ================================================================================
#
# PR #1343: add gujarati numerals eval
# Author: rohoswagger
# State: closed
# URL: https://github.com/openai/evals/pull/1343
#
# --- Title Sentiment ---
# Title: [TextClassificationOutputElement(label='NEU', score=0.9547892212867737), TextClassificationOutputElement(label='POS', score=0.032293446362018585), TextClassificationOutputElement(label='NEG', score=0.012917458079755306)]
#
# --- Body Sentiment ---
# Error analyzing sentiment: (Request ID: Root=1-69152512-31992249775e86684a64771c;4e45541c-af47-4908-a1c9-4c9743c18d93)
#
# Bad request:
# index out of range in self
#
# --- Comments Sentiments (2 total) ---
# Comment 1 by rohoswagger: [TextClassificationOutputElement(label='POS', score=0.9889193177223206), TextClassificationOutputElement(label='NEU', score=0.009619860909879208), TextClassificationOutputElement(label='NEG', score=0.0014608381316065788)]
# Comment 2 by usama-openai: [TextClassificationOutputElement(label='POS', score=0.9906548857688904), TextClassificationOutputElement(label='NEU', score=0.007968220859766006), TextClassificationOutputElement(label='NEG', score=0.0013768754433840513)]
#
# ================================================================================
#
#
# Saving sentiments to file...
#
# Error analyzing sentiment: (Request ID: Root=1-69152513-72dfd0fc2b9170be0bd240fb;1a3a3245-9218-4e5f-afe6-86de3690b6b1)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152513-740d9bcf383e1a1918d5617c;34df29f0-8fc1-4a94-8186-da30ad4a5064)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152513-071e2b0857e024de195f7c90;96cef2a6-7925-4e86-8b2c-e23441937f80)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152515-5525eacc28a384f6167829b6;55ffe957-74db-4bb8-8a20-75f02c2ad122)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152517-18e0afd55cc4471b413802a0;ca1bd2be-f377-4a30-b3e6-0b1f28ac0e48)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152518-1b11d46971693dbf3f735fc1;ba77d928-5348-4166-aa14-3e1fd0039a52)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152519-41d97eaa7e9e05c81c57d21c;0e819603-de27-46df-ae47-1385a8790231)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152519-4362f9d67c9419423c5760a7;fb251560-4d4e-479d-b28a-d0c2d13dff75)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152519-57d34be92e676ab930bb0117;c3072a37-c7a1-4d11-ad67-727088ef1283)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915251a-19ac5cbe22fce4992337de29;4bdd4810-deda-425c-add7-7694a62f15fa)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915251a-0fc0a4436031d6ae739762fd;d1dc7a3e-098d-4c81-abe5-e7c86609aaea)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915251b-22fde974562c73aa63db768e;0f5fb2fd-37d7-41a9-b01e-68e8f7fb7845)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915251b-5bd5fb4d0e82cc4d051dd849;90a38860-cbf7-4179-82de-9b7ebe0250f4)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915251c-0c4d2aa3159a5d583e0c452a;8c62f7da-f298-465c-8ddb-9b2112a501b6)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915251c-2f65d6e034ba14d53ee15001;ab31d04b-7153-4f1f-aa95-db4eb70eb01d)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915251d-21f4c0a360a6706f64aa8d97;b6dc3b51-202c-4997-b744-a34676ffe66d)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915251f-1e4825305fd3c8b53a84e390;d78afdaa-71d5-4540-9609-1ebe48e293c5)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915251f-38b922d7430d965175a6df59;b2ee6a2d-6fd7-4564-a71d-d3f39b329a07)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152520-3f41c5e1551aeb9a4f4da778;c99d84ef-36f2-4eee-8486-16f07d97b10e)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152520-11099d8425a190e719923195;09d57263-caa9-4616-b609-2e76bc9c27a1)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152523-155518cb078e3aa54b511504;063aa765-592a-4385-80e2-9ce78f8359a4)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152523-517d7c1b57ed649b13b93896;296fde4e-3aeb-4f37-8578-1ccc13eaf723)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152524-40f7143778e8f4d30642c37a;8db407ba-c767-4371-a9b8-a8eba856a4f2)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152524-17ee43fa5649ef1456d1f5dd;97e160e9-ec39-4c2e-a7f1-852ae2940967)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152525-7d16d1bf3d3128ef5d1f6fe6;e44d21f6-fe5c-4aa8-9da5-22fc5eb2e0fb)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152526-4b05edb2764e72aa3c91c838;15408a83-1f84-4c78-81c1-542720d17c6b)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152526-2228380a7dfbca20407b5e92;4bfcb81d-4388-42f3-ba54-8f8d15f55994)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152527-098448510c078f2b6545e06c;3a7a5caa-5d1e-457f-bb89-5720288258af)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915252d-1731f6394697b8e772fee630;79dc509a-e795-4a34-867b-2565c1f25178)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915252d-600773c339e9a8886c6b23c1;83d7bfdf-95d1-4511-aad4-2ee1e197a6f6)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152530-7c727bf93216c14b1fbe04c6;4707be1b-a44c-46fe-b849-76c94c50679f)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152530-46b4cd127ffd53d240463d07;099a5c33-5bca-4b82-81f4-2b06e0d77103)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152531-4238f5f11ae52bc27de050e2;97cbb9de-b11c-403c-bb20-8faa145fc88c)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152531-474534b45bb37b5b7dd90083;e67f79fd-031a-42ee-9c51-585134fb0149)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152531-3b5ec1031adadf6523805643;5ec55d7a-12c3-42de-8075-71d77308894d)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152531-49b762206956664e40cbeba4;2b8e4344-acbe-4d18-ad4b-b5da106f2f17)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152532-740a899b3809e56d5eed1e9a;c73044b7-3161-41dc-b827-b8dadd795e95)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152536-60888ede0d04730b13e6438f;d8ed3add-aa35-4b14-92bf-e510dc5b0715)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152536-4a59fe5e3537d93e5c94a829;57520338-dd21-4040-a6c4-bbc97a9fa2e4)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152537-3065d8b07912ada66e243243;dda86d9f-ca8a-4093-ae54-b8859fa6451c)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152538-39e2055732eea17c41bbaf9b;87455583-2522-45ea-8f5e-7a2d19fa5e4b)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-69152538-3c1b871141e3c0dd4bb46c15;2e3dc142-722e-4820-8bff-2eb24167c6a5)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915253a-725db8a91444ba431f4fc378;46c90af7-473a-419b-a315-f20cbfd901fc)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915253b-5711003e177eeb470c63a18f;97a273bb-0c50-4400-9bf4-b40e4643b46d)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915253b-3647366729a7deaa299b5253;aac622b2-039f-4e5c-a8a0-7345c83b27cb)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915253c-5058a8500b0cbd665f689405;2c915601-b59c-4f2e-8d38-0fed64aad5d8)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915253c-008cedbd254c55d85d3776d2;f875d866-75d1-4824-8e84-28ec800f6fe0)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915253d-0952ef38215adffb515f1daf;3c354539-ef00-4b74-adc4-d4a58f9282fc)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915253d-1802c90428d59ccc6a2f5088;a4c5417c-0232-463c-be51-9430c658d5de)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915253d-1e8f033c41716102441c4dc3;79b85ba3-66aa-40ff-a6ec-31a9779464a9)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915253e-276073a75a3974a555ef3201;67e18e8e-ad39-4b8a-a1fc-9b434ce6fb76)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915253e-7da6514c4260a6ca11197c50;83986c30-bfef-4ba1-8b80-cfae6bfd0d75)
#
# Bad request:
# index out of range in self
# Error analyzing sentiment: (Request ID: Root=1-6915253f-6cb2fdf81bebe35207354e7d;ab2d4f77-e5c3-4166-89e2-3897bab9d11c)
#
# Bad request:
# index out of range in self
# Sentiment analysis complete! Results saved to prs_with_sentiments.json
